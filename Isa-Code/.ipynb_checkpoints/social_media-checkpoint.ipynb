# %%
import pandas as pd 
#using this aticlea as reference for text analysis https://towardsdatascience.com/getting-started-with-text-analysis-in-python-ca13590eb4f7
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize
import datetime

# %%
social = pd.read_csv("C:\\Users\\igome\\Documents\\Smith\\Spring_2021\\visual analyticsd\\DC5-data-revised\\YInt Social Media Data\\YInt.csv")

# %%
#converting Timestamp column from object to datetime 
social['time'] = pd.to_datetime(social['time'], format='%Y-%m-%d %H:%M:%S')
social["msgs"] = social["message"].astype(str)

# %%
#Basic questions: What date had the most activity, which had the least?
#social.groupby['time'].sum(
#Looks like April 8th had the most social media activity, april 10th had only 1/3 of the activity of april 8th
msg_amnt = social.groupby([pd.Grouper(key = 'time', freq = '1D')]).count()

msg_amnt['total_messages'] = msg_amnt['message']
msg_amnt[['total_messages']]
# Out:
#             total_messages
# time
# 2020-04-06            8728
# 2020-04-07            7591
# 2020-04-08           12667
# 2020-04-09            8860
# 2020-04-10            4084

# %%
#What location had the most activty?
social.groupby([pd.Grouper(key = 'location')]).count().sort_values(by = 'time', ascending = False)
# Out:
#                                       time  account  message
# location
# Downtown                              4718     4718     4714
# Weston                                4641     4641     4641
# Southton                              3985     3985     3985
# Southwest                             3371     3371     3370
# Northwest                             2769     2769     2767
# Scenic Vista                          2593     2593     2593
# Palace Hills                          2396     2396     2393
# Old Town                              2327     2327     2327
# Broadview                             2203     2203     2202
# Cheddarford                           2090     2090     2090
# West Parton                           1909     1909     1909
# Terrapin Springs                      1833     1833     1833
# Safe Town                             1441     1441     1441
# Oak Willow                            1399     1399     1399
# ...

# %%
#Who were the top 5 accounts? 
social.groupby([pd.Grouper(key = 'account')]).count().sort_values(by = 'time', ascending = False).head(10)
# Out:
#                   time  location  message
# account
# DerekNolan         175       175      175
# Syndicated4        120       120      120
# ChloeJohnson       110       110      110
# ______3333_____    103       103      103
# Syndicated348      102       102      102
# CantonCoordon2      88        88       88
# CassieStones        80        80       80
# Syndicated5         78        78       78
# Opportunities2      75        75       75
# JordanWantsBac0n    73        73       73

# %%
#what is the most common number of messages 
accounts = social.groupby([pd.Grouper(key = 'account')]).count().sort_values(by = 'time', ascending = False)

accounts['total_number_msg'] = accounts['time']
accounts['total_num_users'] = accounts['location']

accounts.groupby([pd.Grouper(key = 'total_number_msg')]).count().sort_values(by = 'total_num_users', ascending = False)
# Out:
#                   time  location  message  total_num_users
# total_number_msg
# 4                  419       419      419              419
# 5                  397       397      397              397
# 6                  390       390      390              390
# 3                  375       375      375              375
# 7                  360       360      360              360
# 8                  359       359      359              359
# 1                  295       295      295              295
# 9                  295       295      295              295
# 10                 284       284      284              284
# 2                  269       269      269              269
# 12                 229       229      229              229
# 11                 223       223      223              223
# 13                 181       181      181              181
# 14                 161       161      161              161
# 15                 141       141      141              141
# ...

# %%
#time we're interested in, we believe the crime happened during this time. 

social6 = social[social['time'].dt.strftime('%Y-%m-%d') == '2020-04-06']
social7 = social[social['time'].dt.strftime('%Y-%m-%d') == '2020-04-07']
social8 = social[social['time'].dt.strftime('%Y-%m-%d') == '2020-04-08']
social9 = social[social['time'].dt.strftime('%Y-%m-%d') == '2020-04-09']
social10 = social[social['time'].dt.strftime('%Y-%m-%d') == '2020-04-10']

# %%
#On April 8, what time had the highest peak of activity?
social8.groupby([pd.Grouper(key = 'time', freq = '1H')]).count().sort_values(by = 'location', ascending = False).head(10)
# Out:
#                      location  account  message  msgs  prep
# time
# 2020-04-08 14:00:00      2106     2106     2106  2106  2106
# 2020-04-08 15:00:00      1305     1305     1305  1305  1305
# 2020-04-08 13:00:00      1179     1179     1179  1179  1179
# 2020-04-08 07:00:00       962      962      962   962   962
# 2020-04-08 09:00:00       861      861      861   861   861
# 2020-04-08 19:00:00       819      819      819   819   819
# 2020-04-08 18:00:00       711      711      711   711   711
# 2020-04-08 08:00:00       658      658      658   658   658
# 2020-04-08 16:00:00       649      649      649   649   649
# 2020-04-08 17:00:00       586      586      585   586   586

# %%
social10.groupby([pd.Grouper(key = 'time', freq = '1H')]).count().sort_values(by = 'location', ascending = False).head(10)
# Out:
#                      location  account  message  msgs  prep
# time
# 2020-04-10 07:00:00       766      766      765   766   766
# 2020-04-10 09:00:00       617      617      617   617   617
# 2020-04-10 11:00:00       536      536      536   536   536
# 2020-04-10 00:00:00       470      470      470   470   470
# 2020-04-10 05:00:00       368      368      368   368   368
# 2020-04-10 10:00:00       357      357      357   357   357
# 2020-04-10 08:00:00       312      312      312   312   312
# 2020-04-10 04:00:00       236      236      236   236   236
# 2020-04-10 03:00:00       171      171      171   171   171
# 2020-04-10 06:00:00       144      144      144   144   144

# %%
#Who were the top 5 accounts on April 8? 
social8.groupby([pd.Grouper(key = 'account')]).count().sort_values(by = 'time', ascending = False).head(10)
# Out:
#                                time  location  message
# account
# DerekNolan                       81        81       81
# ChloeJohnson                     71        71       71
# CassieStones                     63        63       63
# AdministratorSophie              51        51       51
# ChemistryTeacherRichardNelson    45        45       45
# TonyPeterson                     44        44       44
# RachelSimmons                    40        40       40
# OldTownBlues                     36        36       36
# TVHostBrad                       34        34       34
# DOT-StHimark                     22        22       22

# %%
#What location had the most activty on April 8?
social8.groupby([pd.Grouper(key = 'location')]).count().sort_values(by = 'time', ascending = False)
# Out:
#                                       time  account  message
# location
# Downtown                              1552     1552     1552
# Weston                                1448     1448     1448
# Southton                              1158     1158     1158
# Palace Hills                          1040     1040     1039
# Northwest                             1023     1023     1022
# Southwest                              961      961      960
# Scenic Vista                           806      806      806
# Cheddarford                            703      703      703
# Old Town                               686      686      686
# West Parton                            659      659      659
# Broadview                              474      474      474
# Terrapin Springs                       426      426      426
# Safe Town                              332      332      332
# Chapparal                              300      300      300
# ...

# %%
#NOT MY CODE: CODE FROM https://towardsdatascience.com/getting-started-with-text-analysis-in-python-ca13590eb4f7
import re
from nltk.stem import WordNetLemmatizer, PorterStemmer, SnowballStemmer
stop_words_file = "C:\\Users\\igome\\Documents\\Smith\\Spring_2021\\visual analyticsd\\DC5-data-revised\\YInt Social Media Data\\english.stop.txt"

stop_words = []

with open(stop_words_file, "r") as f:
    for line in f:
        stop_words.extend(line.split()) 
        
stop_words = stop_words  

def preprocess(raw_text):
    
    #regular expression keeping only letters 
    letters_only_text = re.sub("[^a-zA-Z]", " ", raw_text)

    # convert to lower case and split into words -> convert string into list ( 'hello world' -> ['hello', 'world'])
    words = letters_only_text.lower().split()

    cleaned_words = []
    lemmatizer = PorterStemmer() #plug in here any other stemmer or lemmatiser you want to try out
    
    # remove stopwords
    for word in words:
        if word not in stop_words:
            cleaned_words.append(word)
    
    # stemm or lemmatise words
    stemmed_words = []
    for word in cleaned_words:
        word = lemmatizer.stem(word)   #dont forget to change stem to lemmatize if you are using a lemmatizer
        stemmed_words.append(word)
    -versus-a-copy
  """Entry point for launching an IPython kernel.

    # converting list back to string
    return " ".join(stemmed_words)

# %%
social6['prep'] = social6['msgs'].apply(preprocess)
social7['prep'] = social7['msgs'].apply(preprocess)
social8['prep'] = social8['msgs'].apply(preprocess)
social9['prep'] = social9['msgs'].apply(preprocess)
social10['prep'] = social10['msgs'].apply(preprocess)
# Out:
# C:\Users\igome\anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
# C:\Users\igome\anaconda3\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\igome\anaconda3\lib\site-packages\ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# ...

# %%
social8
# Out:
#                      time          location                   account  \
# 16320 2020-04-08 00:00:00          Southton           FearsDemossBird
# 16321 2020-04-08 00:00:00          Old Town    AttentativeSmithBowl23
# 16322 2020-04-08 00:00:00  Terrapin Springs         LovesMoultonWhale
# 16323 2020-04-08 00:00:00       West Parton          ShielaFastPatton
# 16324 2020-04-08 00:00:00         Safe Town        FuriousWillieLight
# ...                   ...               ...                       ...
# 28985 2020-04-08 23:59:00         Southwest  DarkCandyMary_Moorehouse
# 28986 2020-04-08 23:59:00  Terrapin Springs          FamousBakerCar17
# 28987 2020-04-08 23:59:00      Palace Hills        AttentativeEBanana
# 28988 2020-04-08 23:59:00  Terrapin Springs           HoldsOgdenMouse
# 28989 2020-04-08 23:59:00          Southton               FuriousWCar
#
#                                                  message  \
# 16320  re: My girlfriend's veal was very popular when...
# ...

# %%
#april 6
from collections import Counter
Counter(" ".join(social6["prep"]).split()).most_common(10)
# Out:
# [('great', 508),
#  ('good', 491),
#  ('day', 432),
#  ('work', 408),
#  ('time', 374),
#  ('movi', 356),
#  ('place', 334),
#  ('love', 309),
#  ('don', 296),
#  ('make', 270)]

# %%
Counter(" ".join(social7["prep"]).split()).most_common(10)
# Out:
# [('time', 581),
#  ('work', 438),
#  ('good', 365),
#  ('don', 288),
#  ('love', 282),
#  ('day', 268),
#  ('make', 242),
#  ('great', 202),
#  ('place', 201),
#  ('quot', 189)]

# %%
Counter(" ".join(social8["prep"]).split()).most_common(10)
# Out:
# [('water', 727),
#  ('power', 649),
#  ('peopl', 555),
#  ('citi', 494),
#  ('safe', 471),
#  ('shelter', 471),
#  ('work', 463),
#  ('build', 450),
#  ('damag', 399),
#  ('town', 343)]

# %%
Counter(" ".join(social9["prep"]).split()).most_common(10)
# Out:
# [('peopl', 528),
#  ('work', 520),
#  ('power', 489),
#  ('nuclear', 469),
#  ('citi', 448),
#  ('bridg', 389),
#  ('water', 387),
#  ('open', 387),
#  ('hss', 385),
#  ('food', 357)]

# %%
Counter(" ".join(social10["prep"]).split()).most_common(10)
# Out:
# [('power', 188),
#  ('shelter', 179),
#  ('ferret', 175),
#  ('food', 161),
#  ('peopl', 143),
#  ('vanessacorwin', 134),
#  ('kyle', 130),
#  ('make', 129),
#  ('good', 127),
#  ('nuclear', 126)]

# %%
#nice library to produce wordclouds
#used following link to change color of txt:python-graph-gallery.com/261-custom-python-wordcloud

from wordcloud import WordCloud

import matplotlib.pyplot as plt
# if uising a Jupyter notebook, include:
# %matplotlib inline

all_words = '' 

#looping through all incidents and joining them to one text, to extract most common words
for arg in social6["prep"]: 

    tokens = arg.split()  
      
    all_words += " ".join(tokens)+" "

wordcloud = WordCloud(width = 700, height = 700, 
                background_color ='white', 
                colormap="tab10",
                min_font_size = 10).generate(all_words) 
  
# plot the WordCloud image                        
plt.figure(figsize = (5, 5), facecolor = None) 
plt.imshow(wordcloud) 
plt.axis("off") 
plt.tight_layout(pad = 0) 
  
plt.show()

# %%
# if uising a Jupyter notebook, include:
# %matplotlib inline

all_words = '' 

#looping through all incidents and joining them to one text, to extract most common words
for arg in social7["prep"]: 

    tokens = arg.split()  
      
    all_words += " ".join(tokens)+" "

wordcloud = WordCloud(width = 700, height = 700, 
                background_color ='white', 
                colormap="tab10",
                min_font_size = 10).generate(all_words) 
  
# plot the WordCloud image                        
plt.figure(figsize = (5, 5), facecolor = None) 
plt.imshow(wordcloud) 
plt.axis("off") 
plt.tight_layout(pad = 0) 
  
plt.show()

# %%
# if uising a Jupyter notebook, include:
# %matplotlib inline

all_words = '' 

#looping through all incidents and joining them to one text, to extract most common words
for arg in social8["prep"]: 

    tokens = arg.split()  
      
    all_words += " ".join(tokens)+" "

wordcloud = WordCloud(width = 700, height = 700, 
                background_color ='white',
                colormap="tab10",
                min_font_size = 10).generate(all_words) 
  
# plot the WordCloud image                        
plt.figure(figsize = (5, 5), facecolor = None) 
plt.imshow(wordcloud) 
plt.axis("off") 
plt.tight_layout(pad = 0) 
  
plt.show()

# %%
# if uising a Jupyter notebook, include:
# %matplotlib inline

all_words = '' 

#looping through all incidents and joining them to one text, to extract most common words
for arg in social9["prep"]: 

    tokens = arg.split()  
      
    all_words += " ".join(tokens)+" "

wordcloud = WordCloud(width = 700, height = 700, 
                background_color ='white', 
                colormap="tab10",
                min_font_size = 10).generate(all_words) 
  
# plot the WordCloud image                        
plt.figure(figsize = (5, 5), facecolor = None) 
plt.imshow(wordcloud) 
plt.axis("off") 
plt.tight_layout(pad = 0) 
  
plt.show()

# %%
# if uising a Jupyter notebook, include:
# %matplotlib inline

all_words = '' 

#looping through all incidents and joining them to one text, to extract most common words
for arg in social10["prep"]: 

    tokens = arg.split()  
      
    all_words += " ".join(tokens)+" "

wordcloud = WordCloud(width = 700, height = 700, 
                background_color ='white', 
                colormap="tab10",
                min_font_size = 10).generate(all_words) 
  
# plot the WordCloud image                        
plt.figure(figsize = (5, 5), facecolor = None) 
plt.imshow(wordcloud) 
plt.axis("off") 
plt.tight_layout(pad = 0) 
  
plt.show()

# %%
from nltk.util import ngrams
n_gram = 2
n_gram_dic = dict(Counter(ngrams(all_words.split(), n_gram)))

for i in n_gram_dic:
    if n_gram_dic[i] >= 50:
        print(i, n_gram_dic[i])
# Out:
# ('power', 'plant') 139
# ('nuclear', 'energi') 56
# ('nuclear', 'power') 198
# ('download', 'rumbl') 52
# ('boil', 'water') 87
# ('app', 'inform') 86
# ('lot', 'peopl') 57
# ('st', 'himark') 182
# ('mr', 'tillenbottom') 58
# ('build', 'collaps') 66
# ('krak', 'tv') 128
# ('jade', 'bridg') 64
# ('rescu', 'worker') 56
# ('juli', 'bridg') 52
# ('bridg', 'close') 161
# ('close', 'notic') 132
# ('notic', 'precautionari') 136
# ('precautionari', 'action') 145
# ('action', 'pend') 147
# ('pend', 'safeti') 132
# ('safeti', 'inspect') 132
# ('inspect', 'rout') 145
# ('citi', 'evacu') 131
# ('open', 'close') 80
# ('find', 'shelter') 94
# ('fatal', 'news') 72
# ('fire', 'station') 60
# ('long', 'road') 62
# ('road', 'ahead') 62
# ('bottl', 'water') 59
# ('disast', 'shelter') 85
# ('die', 'don') 56
# ('structur', 'integr') 132
# ('integr', 'failur') 131
# ('failur', 'problem') 75
# ('problem', 'inspect') 73
# ('inspect', 'damag') 133
# ('damag', 'defect') 133
# ('defect', 'test') 134
# ...
